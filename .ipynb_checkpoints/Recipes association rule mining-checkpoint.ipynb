# %% [markdown]
# # Association rule mining for recipetin eats recipes
# Objective: find most common combinations and ratios of flavours in different cuisines

# %% [markdown]
# # Import libraries and set directories

# %%
# pip install apyori
# %pip install networkx
# pip install plotly==5.9.0

# %%
# Import standard libraries
import numpy as np
import pandas as pd
import plotly.express as px

# Functional libraries
import glob
from datetime import date
from apyori import apriori
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Set max rows and columns
pd.options.display.max_columns = 50
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', -1)

# Set directory
filepath = r'/Users/lesliemarsh/Documents/Recipe_Scraping'

# %% [markdown]
# # Import recipe csv

# %%
cuisine_name = 'vietnamese'
cuisine = pd.read_csv(filepath + f"/{cuisine_name}.csv")

# Drop and reorder columns
cuisine = cuisine[['meal', 'servings', 'name', 'amount', 'unit', 'notes']]

# Set new dataframe name to be able to loop through files later
df = cuisine

# %%
df.head()
# Out:
#                        meal  servings                        name     amount  \
# 0  Vietnamese Chicken Salad  3         cooked chicken              350g/12oz
# 1  Vietnamese Chicken Salad  3         heaped cups wombok cabbage  6
# 2  Vietnamese Chicken Salad  3         red onion                   1/2
# 3  Vietnamese Chicken Salad  3         red capsicum / bell pepper  1
# 4  Vietnamese Chicken Salad  3         cucumbers                   2
#
#   unit  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#                                                                                       notes
# 0  cut into thin batons (2 large cooked breasts, Note 1)
# 1  (Napa cabbage), finely shredded (Note 2)
# 2  very finely sliced (so it’s floppy)
# 3  finely sliced into thin batons
# 4  remove seeds then finely sliced into half moons (or 1 long continental/English cucumber)

# %% [markdown]
# # Clean dataframe

# %%
# Ensure columns conform to same spelling

# Ensure all unit values are lowercase
df.loc[:, "unit"] = df.loc[:, "unit"].str.lower()

# Conform cup
df.loc[df['unit'].str.contains("cup", na = False), 'unit'] = 'cup'

# Conform tbsp
df.loc[df['unit'].str.contains("tbsp", na = False), 'unit'] = 'tbsp'

# Conform tsp
df.loc[df['unit'].str.contains("tsp", na = False), 'unit'] = 'tsp'
df.loc[df['unit'].str.contains("teaspoon", na = False), 'unit'] = 'tsp'

# Conform cloves
df.loc[df['unit'].str.contains("clove", na = False), 'unit'] = 'clove'

# Check unique unit values
# df['unit'].unique()

# Ensure all name values are lowercase
df.loc[:, "name"] = df.loc[:, "name"].str.lower()

# By displaying the values in alphabetical order there is a better chance at finding
# the same ingredient spelled or written differently. astype used in case of ints in series
#sorted(list(df['name'].astype('str').unique()))

# Create list of foods to cycle through
foods = ['chilli', 'white sugar', 'red onion', 'dark soy sauce', 'light soy sauce', 'soy sauce', 'brown sugar', 'rice vinegar', 'basil', 'coriander', 'salt and pepper'
         , 'black vinegar', 'balsamic vinegar', 'tomato paste', 'bok choy', 'tomato sauce', 'salt', 'white pepper', 'black pepper', 'pepper', 'peanut butter', 'lemongrass', 'coconut', 'thai seasoning'
         , 'shallot', 'sugar', 'chicken stock', 'fish sauce', "galangal", 'olive oil', 'parsley', 'oregano', 'peas' 
        , 'kaffir lime', 'lime zest', 'lime', 'hoisin', 'red onion', 'onion', 'mint', 'cinnamon', 'parmesan', 'rosemary'
         , 'red curry paste', 'tamarind', 'egg', 'beansprouts', 'mango', 'cardamom', 'dill', 'olives'
         , 'cumin',  'garlic', 'clove', 'hoisin', 'chinese cooking wine', 'five spice', 'curry powder', 'thyme'
        , 'capsicum', 'cream', 'butter', 'tomato', 'bacon', 'white wine', 'red wine', 'rosemary', 'bay leaves', 'milk'
        , 'tumeric', 'gochujang', 'chipotle', 'paprika', 'allspice', 'clove', 'garam masala', 'yoghurt', 'fennel', 'sumac'
        , 'tahini', 'cilantro', 'couscous', 'preserved lemon', 'avocado', 'chicken broth', 'chicken stock', 'ginger', 'star anise'
        , 'sriracha', 'baking soda', 'sesame oil', 'sichuan pepper', 'tofu', 'lemongrass', 'oyster sauce', 'sambal oelek', 'tahini'
        , 'beef stock', 'cayenne', 'chervil', 'white wine', 'red wine', 'eschalot', 'gruyere', 'butter', 'tarragon'
        , 'sage', 'ajwain', 'curry leaves', 'fenugreek', 'italian herbs', 'mossarella', 'ricotta', 'kimchi', 'feta', 'nutmeg'
        , 'lemon juice', 'lemon zest', 'lemon rind', 'lemon', 'olives', 'saffron', 'vinegar', 'hot sauce', 'guacamole'
        , 'cheese', 'jalapeno', 'peanuts', 'green curry paste', 'red currry paste', 'shrimp paste']

# Create dict of misspellings to cycle through
foods_spell = {'chili': 'chilli', 'chicken broth': 'chicken stock', 'beef broth': 'beef stock'
              , 'lemon grass': 'lemongrass', 'bean sprouts': 'beansprouts', 'cornflour': 'cornflour/cornstarch'
              , 'cornstarch': 'cornflour/cornstarch', 'oyster': 'oyster sauce', 'zest': 'lemon zest', 'bay leaf': 'bay leaves'
              , 'turmeric': 'tumeric', 'grated cheese': 'parmesan', 'kochujang': 'gochujang', 'all spice': 'allspice'
              , 'chicken or vegetable stock': 'chicken stock', 'chicken or vegetable broth (or water)': 'chicken stock'
              , 'cilantro': 'coriander', 'chicken or vegetable': 'chicken stock', 'scallions': 'spring onions'
              , 'green onions': 'spring onions', 'sesame paste': 'tahini', 'ketchup': 'tomato sauce', 'beef broth': 'beef stock'
              , 'eschallot': 'eschalot', 'cardamon': 'cardamom', 'garam marsala': 'garam masala', 'yogurt': 'yoghurt'
              , 'anchovy': 'anchovies', 'beef bouillon': 'beef stock', 'chicken bouillon': 'chicken stock', 'bayleaves': 'bay leaves'}

single_foods = [food for food in foods if ' ' not in food]

double_foods = [food for food in foods if ' ' in food]

# Cycle through double foods list removing extraeneous words 
for i in double_foods:
    df.loc[(df['name'].str.contains(i, na = False)), 'name'] = i

# Cycle through single foods, ignoring double words, removing extraeneous words
for i in single_foods:
    df.loc[(~df['name'].str.contains('|'.join(double_foods),na = False)) & (df['name'].str.contains(i)), 'name'] = i

# Cycle through differently spelled words replacing word with unified spelling
for i in foods_spell:
    df.loc[df['name'].str.contains(i, na = False), 'name'] = foods_spell[i]
# Out:
# /Users/lesliemarsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:70: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.

# %% [markdown]
# ## Deal with non float units

# %%
# Create new units dictionary and replace values
frac = {'1/2': '0.25', '1/4': '0.25', '1/3': '0.33', '1 1/2': '1.5', '2/3': '0.67'
        , '2 1/2': '2.5', '1 - 2': '1.5', '3/4': '.75', ' ': ''}
df['amount'] = df['amount'].replace(frac)

# %%
# May not need this
df['amount'] = df['amount'].replace(' ', '', regex = True)

# %%
# Extract all amounts with grams and add amount to amount_float column and...
(df.loc[df['amount']
        .str.contains(r'(\d+)(g)', na=False), 'amount_float']) = (df['amount']
                                                                  .str.extract(r'(\d+)(g)')[0]
                                                                 )
# ...add unit to units column
(df.loc[df['amount']
        .str.contains(r'(\d+)(g)', na=False), 'unit']) = (df['amount']
                                                                  .str.extract(r'(\d+)(g)')[1]
                                                                 )

# Extract all amounts with mls and add amount to amount_float column and...
(df.loc[df['amount']
        .str.contains(r'(\d+)(ml)', na=False), 'amount_float']) = (df['amount']
                                                                  .str.extract(r'(\d+)(ml)')[0]
                                                                 )
# ...add unit to units column
(df.loc[df['amount']
        .str.contains(r'(\d+)(ml)', na=False), 'unit']) = (df['amount']
                                                                  .str.extract(r'(\d+)(ml)')[1]
                                                                 )
# Out:
# /Users/lesliemarsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.
#
# /Users/lesliemarsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.
#
# /Users/lesliemarsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.
#
# /Users/lesliemarsh/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: UserWarning:
#
# This pattern has match groups. To actually get the groups, use str.extract.

# %%
df['amount'].unique()
# Out:
# array(['350g/12oz', '6', '0.25', '1', '2', '5cm/2"', '2litres/2quarts',
#        '1.5kg/3lb', '5', '4', '8', '.75', '360g/13oz', '3', nan,
#        '150g/5oz', '10', '1.5', '1kg/2lb', '3.5litres/3.75quarts',
#        '40ml/3tbsp', '50g/1.5oz', '30g/1oz', '3-5', '600-800g/1.2-1.6lb',
#        '200g/7oz', '1lb/500g', '4-8', '11/2cups(375ml)', '1/2cup(100g)',
#        '3/4cup(185ml)', '0.67', '500g/1lb', '500g/1lb(3cups)', '2.5',
#        '250–300g/8–10oz', '0.33', '100g/3.5oz', '4large/5small',
#        '1/2cup/80g', '400g/14oz', '1/2cup/100g', '1.5cups/375ml', '7-14',
#        '11', '7', '14', '12-15', '2.5oz/75g', '2lb/1kg', '500g/1lbs',
#        '1⁄4', '1⁄2', '200'], dtype=object)

# %%
df.head()
# Out:
#                        meal  servings                        name     amount  \
# 0  Vietnamese Chicken Salad  3         cooked chicken              350g/12oz
# 1  Vietnamese Chicken Salad  3         heaped cups wombok cabbage  6
# 2  Vietnamese Chicken Salad  3         red onion                   0.25
# 3  Vietnamese Chicken Salad  3         pepper                      1
# 4  Vietnamese Chicken Salad  3         cucumbers                   2
#
#   unit  \
# 0  g
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#                                                                                       notes  \
# 0  cut into thin batons (2 large cooked breasts, Note 1)
# 1  (Napa cabbage), finely shredded (Note 2)
# 2  very finely sliced (so it’s floppy)
# 3  finely sliced into thin batons
# 4  remove seeds then finely sliced into half moons (or 1 long continental/English cucumber)
#
#   amount_float
# 0  350
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN

# %% [markdown]
# ## Create unit mapping

# %%
food_type = {'herb': {'chilli', 'clove', 'coriander', 'parsley', 'thyme', 'bay leaf', 'lemon zest', 'oregano'
                     , 'lemongrass', 'clove', 'star anise', 'basil'}
            ,'liquid': {'lime', 'fish sauce', 'soy sauce', 'water', 'sesame oil', 'chinese cooking wine'
                       ,'oyster sauce', 'olive oil', 'mirin', 'chicken stock', 'cream', 'vegetable oil'
                       , 'hoisin', 'sriracha', 'lemon juice'}
            , 'powder': {'white sugar', 'brown sugar', 'sugar', 'pepper', 'cornflour/cornstarch', 'salt'
                        , 'cumin', 'black mustard seeds', 'parmesan', 'paprika', 'cinnamon', 'turmeric', 'black pepper'}
            , 'solid': {'onion', 'garlic', 'egg', 'tomato', 'ginger', 'carrot', 'peas', 'coconut'
                        , 'beansprouts', 'avocado'}
            }

# %%
# Create function that checks if value is in dictionary and returns key
def food_type_map(x):
    if str(x) in str(food_type.values()): # String wrapper necessary because of multi indexed dict
        try:
            return [key for key, val in food_type.items() if str(x) in val][0]
        except (IndexError, TypeError):
            return np.nan
    else:
        return np.nan

# %%
df['food_type'] = df['name'].apply(lambda x: food_type_map(x))

# %%
unit_conv = {'tsp': {'herb': 2, 'liquid': 4.67, 'powder': 2.83, 'solid': 3.23}
             , 'tbsp': {'herb': 6, 'liquid': 15.5, 'powder': 8.5, 'solid': 9.7}
             , 'cup': {'herb': 96, 'liquid': 248, 'powder': 136, 'solid': 155}
               }   

# Create function to check food type column and then multiply amount column by gram scalar
def imperial_to_metric(unit, food_type, amount):
    try:
        return unit_conv[unit][food_type] * amount
    except: KeyError
    return np.nan

# %%
df.loc[df['amount_float'].isna(), 'amount_float'] = pd.to_numeric(df['amount'], errors = np.nan)

# Create metric column by creating a function and using other columns as inputs using a vector method
df['metric'] = np.vectorize(imperial_to_metric)(df['unit'], df['food_type'], df['amount_float'])

df.loc[~df['unit'].str.contains('cup|tbsp|tsp', na = False), 'metric'] = df['amount_float']

# %%
# Adjust for servings
df['servings'] = pd.to_numeric(df['servings'], errors = np.nan)
df['metric'] = pd.to_numeric(df['metric'], errors = np.nan)
df['amount_for_4_serves'] = round(df['metric']*(4/df['servings']), 2)

# %%
df.head()
# Out:
#                        meal  servings                        name     amount  \
# 0  Vietnamese Chicken Salad  3         cooked chicken              350g/12oz
# 1  Vietnamese Chicken Salad  3         heaped cups wombok cabbage  6
# 2  Vietnamese Chicken Salad  3         red onion                   0.25
# 3  Vietnamese Chicken Salad  3         pepper                      1
# 4  Vietnamese Chicken Salad  3         cucumbers                   2
#
#   unit  \
# 0  g
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#                                                                                       notes  \
# 0  cut into thin batons (2 large cooked breasts, Note 1)
# 1  (Napa cabbage), finely shredded (Note 2)
# 2  very finely sliced (so it’s floppy)
# 3  finely sliced into thin batons
# 4  remove seeds then finely sliced into half moons (or 1 long continental/English cucumber)
#
#   amount_float food_type  metric  amount_for_4_serves
# 0  350          NaN       350.00  466.67
# 1  6            NaN       6.00    8.00
# 2  0.25         NaN       0.25    0.33
# 3  1            powder    1.00    1.33
# 4  2            NaN       2.00    2.67

# %% [markdown]
# # Apply apriori algorith

# %%
# Reduce data frame
df_reduce = df[['meal', 'name']]

# Reshape data frame
df_reduce = (df_reduce.set_index(['meal', df.groupby('meal').cumcount()])['name']
       .unstack(fill_value=0)
       .rename(columns = lambda x: f'n{x + 1}')
       .reset_index())

# Replace all 0 with NaN
df_reduce.replace(0, np.nan, inplace = True)

# Create numpy array of all items
transaction = []
for i in range(0, df_reduce.shape[0]):
    for j in range(0, df_reduce.shape[1]):
        transaction.append(df_reduce.values[i,j])

# Convert to numpy array
transaction = np.array(transaction)

# Convert to dataframe
df_trans = pd.DataFrame(transaction, columns = ['items'])

# Put 1 to Each Item For Making Countable Table, to be able to perform Group By
df_trans["incident_count"] = 1

# Delete NaNs 
indexNames = df_trans[df_trans['items'] == 'nan'].index

df_trans.drop(indexNames, inplace = True)

# Making a new dataframe for visualizations  
df_table = df_trans.groupby("items").sum().sort_values("incident_count", ascending=False).reset_index()

# Initial visualisations
df_table.head(10).style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row0_col1 {
#             background-color:  #00441b;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row1_col1 {
#             background-color:  #087432;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row2_col1 {
#             background-color:  #309950;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row3_col1 {
#             background-color:  #45ad5f;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row4_col1 {
#             background-color:  #9ed798;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row5_col1 {
#             background-color:  #def2d9;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row6_col1 {
#             background-color:  #def2d9;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row7_col1 {
#             background-color:  #ecf8e8;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row8_col1 {
#             background-color:  #ecf8e8;
#         }    #T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row9_col1 {
#             background-color:  #f7fcf5;
#         }</style>
# <table id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >items</th>
#         <th class="col_heading level0 col1" >incident_count</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row0_col0" class="data row0 col0" >chilli</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row0_col1" class="data row0 col1" >20</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row1_col0" class="data row1 col0" >garlic</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row1_col1" class="data row1 col1" >18</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row2_col0" class="data row2 col0" >fish sauce</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row2_col1" class="data row2 col1" >16</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row3_col0" class="data row3 col0" >lime</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row3_col1" class="data row3 col1" >15</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row4_col0" class="data row4 col0" >coriander</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row4_col1" class="data row4 col1" >12</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row5_col0" class="data row5 col0" >white sugar</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row5_col1" class="data row5 col1" >9</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row6_col0" class="data row6 col0" >onion</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row6_col1" class="data row6 col1" >9</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row7_col0" class="data row7 col0" >water</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row7_col1" class="data row7 col1" >8</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row8_col0" class="data row8 col0" >brown sugar</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row8_col1" class="data row8 col1" >8</td>
#     </tr>    <tr>
#         <th id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3level0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row9_col0" class="data row9 col0" >soy sauce</td>
#         <td id="T_5170f9a0_46e1_11ed_840c_20c9d07f6cc3row9_col1" class="data row9 col1" >7</td>
#     </tr></tbody>
# </table>

# %%
# to have a same origin
df_table["all"] = "all" 

# creating tree map using plotly
fig = px.treemap(df_table.head(30), path=['all', "items"], values='incident_count',
                  color=df_table["incident_count"].head(30), hover_data=['items'],
                  color_continuous_scale='Greens'
                )
# Plot the treemap
fig.show()
# Out:
# <div>                            <div id="ddc88475-e37f-4115-8c84-a0ded599ca4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddc88475-e37f-4115-8c84-a0ded599ca4c")) {                    Plotly.newPlot(                        "ddc88475-e37f-4115-8c84-a0ded599ca4c",                        [{"branchvalues":"total","customdata":[["beansprouts",7.0],["brown sugar",8.0],["chilli",20.0],["cinnamon",2.0],["clove",2.0],["coconut",2.0],["coriander",12.0],["cucumbers",3.0],["fish sauce",16.0],["garlic",18.0],["ginger",4.0],["hoisin",3.0],["iceberg lettuce",2.0],["lemon",6.0],["lime",15.0],["mint",5.0],["oil",4.0],["onion",9.0],["pork mince",2.0],["rice vinegar",5.0],["salt",4.0],["soy sauce",7.0],["sriracha",2.0],["star anise",2.0],["vegetable oil",4.0],["vermicelli noodles",2.0],["vinegar",2.0],["water",8.0],["white pepper",3.0],["white sugar",9.0],["(?)",10.372340425531915]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>incident_count=%{value}<br>parent=%{parent}<br>id=%{id}<br>items=%{customdata[0]}<br>color=%{color}<extra></extra>","ids":["all/beansprouts","all/brown sugar","all/chilli","all/cinnamon","all/clove","all/coconut","all/coriander","all/cucumbers","all/fish sauce","all/garlic","all/ginger","all/hoisin","all/iceberg lettuce","all/lemon","all/lime","all/mint","all/oil","all/onion","all/pork mince","all/rice vinegar","all/salt","all/soy sauce","all/sriracha","all/star anise","all/vegetable oil","all/vermicelli noodles","all/vinegar","all/water","all/white pepper","all/white sugar","all"],"labels":["beansprouts","brown sugar","chilli","cinnamon","clove","coconut","coriander","cucumbers","fish sauce","garlic","ginger","hoisin","iceberg lettuce","lemon","lime","mint","oil","onion","pork mince","rice vinegar","salt","soy sauce","sriracha","star anise","vegetable oil","vermicelli noodles","vinegar","water","white pepper","white sugar","all"],"marker":{"coloraxis":"coloraxis","colors":[7.0,8.0,20.0,2.0,2.0,2.0,12.0,3.0,16.0,18.0,4.0,3.0,2.0,6.0,15.0,5.0,4.0,9.0,2.0,5.0,4.0,7.0,2.0,2.0,4.0,2.0,2.0,8.0,3.0,9.0,10.372340425531915]},"name":"","parents":["all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all","all",""],"values":[7,8,20,2,2,2,12,3,16,18,4,3,2,6,15,5,4,9,2,5,4,7,2,2,4,2,2,8,3,9,188],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111 ...

# %% [markdown]
# # Create boolean array of ingredients

# %% [markdown]
# ## Create list of ingredient lists

# %%
# Create list of lists
records = []
for row in range(0, df_reduce.shape[0]):
    records.append([str(df_reduce.values[row, col]) for col in range(0, df_reduce.shape[1]) if str(df_reduce.values[row, col]) != "nan"])

## Create boolean array

te = TransactionEncoder()
te_ary = te.fit(records).transform(records)
df_bool = pd.DataFrame(te_ary, columns=te.columns_)

# %% [markdown]
# # Analyse with apriori algorithm

# %% [markdown]
# ## Find frequent itemsets with support controls

# %%
# Create dictionary tracking supports
supports = {'vietnamese': .15, 'chinese': .2, 'french': .15, 'greek': .3, 'indian': .4
           , 'italian': .27, 'korean': .3, 'mediterranean': .2, 'Mexican': .17
           , 'middle-eastern': .2, 'south-american': .2, 'thai': .25}

# %%
frequent_itemsets = apriori(df_bool, min_support=supports[cuisine_name], use_colnames=True)

# %% [markdown]
# ## Add length column to filter number of ingredients

# %%
frequent_itemsets
# Out:
#       support  \
# 0     0.4375
# 1     0.5000
# 2     0.9375
# 3     0.6250
# 4     0.1875
# 5     0.8125
# 6     0.8125
# 7     0.2500
# 8     0.1875
# 9     0.3750
# 10    0.6875
# 11    0.3125
# 12    0.2500
# 13    0.4375
# 14    0.3125
# 15    0.2500
# 16    0.3125
# 17    0.2500
# 18    0.5000
# 19    0.1875
# 20    0.5000
# 21    0.4375
# 22    0.3750
# 23    0.3125
# 24    0.3125
# 25    0.1875
# 26    0.1875
# 27    0.4375
# 28    0.2500
# 29    0.1875
# 30    0.1875
# 31    0.1875
# 32    0.3125
# 33    0.3125
# 34    0.5000
# 35    0.2500
# 36    0.4375
# 37    0.5000
# 38    0.3125
# 39    0.3125
# 40    0.1875
# 41    0.3125
# 42    0.2500
# 43    0.2500
# 1371  0.1875
# 1372  0.1875
# 1373  0.1875
# 1374  0.1875
# 1375  0.1875
# 1376  0.1875
# 1377  0.1875
# 1378  0.1875
# 1379  0.2500
# 1380  0.2500
# 1381  0.2500
# 1382  0.2500
# 1383  0.2500
# 1384  0.2500
# 1385  0.1875
# 1386  0.1875
# 1387  0.1875
# 1388  0.1875
# 1389  0.2500
# 1390  0.1875
# 1391  0.1875
# 1392  0.1875
# 1393  0.1875
# 1394  0.1875
# 1395  0.2500
# 1396  0.1875
# 1397  0.1875
# 1398  0.1875
# 1399  0.1875
# 1400  0.1875
# 1401  0.1875
# 1402  0.1875
# 1403  0.1875
# 1404  0.1875
# 1405  0.1875
# 1406  0.2500
# 1407  0.1875
# 1408  0.1875
# 1409  0.1875
# 1410  0.1875
# 1411  0.1875
# 1412  0.1875
# 1413  0.1875
# 1414  0.1875
# 1415  0.1875
# 1416  0.1875
# 1417  0.1875
# 1418  0.1875
# 1419  0.2500
# 1420  0.1875
# 1421  0.1875
# 1422  0.1875
# 1423  0.1875
#
#                                                                                          itemsets
# 0     (beansprouts)
# 1     (brown sugar)
# 2     (chilli)
# 3     (coriander)
# 4     (cucumbers)
# 5     (fish sauce)
# 6     (garlic)
# 7     (ginger)
# 8     (hoisin)
# 9     (lemon)
# 10    (lime)
# 11    (mint)
# 12    (oil)
# 13    (onion)
# 14    (rice vinegar)
# 15    (salt)
# 16    (soy sauce)
# 17    (vegetable oil)
# 18    (water)
# 19    (white pepper)
# 20    (white sugar)
# 21    (chilli, beansprouts)
# 22    (coriander, beansprouts)
# 23    (fish sauce, beansprouts)
# 24    (garlic, beansprouts)
# 25    (hoisin, beansprouts)
# 26    (lemon, beansprouts)
# 27    (lime, beansprouts)
# 28    (mint, beansprouts)
# 29    (oil, beansprouts)
# 30    (onion, beansprouts)
# 31    (rice vinegar, beansprouts)
# 32    (water, beansprouts)
# 33    (white sugar, beansprouts)
# 34    (chilli, brown sugar)
# 35    (brown sugar, coriander)
# 36    (brown sugar, fish sauce)
# 37    (brown sugar, garlic)
# 38    (lemon, brown sugar)
# 39    (lime, brown sugar)
# 40    (rice vinegar, brown sugar)
# 41    (soy sauce, brown sugar)
# 42    (brown sugar, vegetable oil)
# 43    (water, brown sugar)
# 44    (chilli, coriander)
# 45    (chilli, cucumbers)
# 46    (chilli, fish sauce)
# 47    (chilli, garlic)
# 48    (chilli, ginger)
# 49    (chilli, hoisin)
# 50    (chilli, lemon)
# 51    (lime, chilli)
# 52    (chilli, mint)
# 53    (chilli, oil)
# 54    (onion, chilli)
# 55    (chilli, rice vinegar)
# 56    (chilli, salt)
# 57    (soy sauce, chilli)
# 58    (chilli, vegetable oil)
# 59    (chilli, water)
# 60    (chilli, white pepper)
# 61    (white sugar, chilli)
# 62    (cucumbers, coriander)
# 63    (fish sauce, coriander)
# 64    (garlic, coriander)
# 65    (lemon, coriander)
# 66    (lime, coriander)
# 67    (mint, coriander)
# 68    (oil, coriander)
# 69    (onion, coriander)
# 70    (rice vinegar, coriander)
# 71    (salt, coriander)
# 72    (soy sauce, coriander)
# 73    (vegetable oil, coriander)
# 74    (water, coriander)
# 75    (white sugar, coriander)
# 76    (white sugar, cucumbers)
# 77    (garlic, fish sauce)
# 78    (fish sauce, ginger)
# 79    (lemon, fish sauce)
# 80    (lime, fish sauce)
# 81    (fish sauce, mint)
# 82    (fish sauce, oil)
# 83    (onion, fish sauce)
# 84    (rice vinegar, fish sauce)
# 85    (salt, fish sauce)
# 86    (soy sauce, fish sauce)
# 87    (fish sauce, vegetable oil)
# 88    (water, fish sauce)
# 89    (white pepper, fish sauce)
# 90    (white sugar, fish sauce)
# 91    (lemon, garlic)
# 92    (lime, garlic)
# 93    (garlic, mint)
# 94    (garlic, oil)
# 95    (onion, garlic)
# 96    (rice vinegar, garlic)
# 97    (soy sauce, garlic)
# 98    (garlic, vegetable oil)
# 99    (water, garlic)
# 100   (white pepper, garlic)
# 101   (white sugar, garlic)
# 102   (onion, ginger)
# 103   (water, ginger)
# 104   (white sugar, ginger)
# 105   (lime, hoisin)
# 106   (lime, lemon)
# 107   (lemon, oil)
# 108   (soy sauce, lemon)
# 109   (lemon, vegetable oil)
# 110   (water, lemon)
# 111   (white sugar, lemon)
# 112   (lime, mint)
# 113   (lime, oil)
# 114   (onion, lime)
# 115   (lime, rice vinegar)
# 116   (lime, salt)
# 117   (soy sauce, lime)
# 118   (lime, vegetable oil)
# 119   (lime, water)
# 120   (white sugar, lime)
# 121   (rice vinegar, mint)
# 122   (white sugar, mint)
# 123   (water, oil)
# 124   (white sugar, oil)
# 125   (onion, salt)
# 126   (onion, water)
# 127   (white sugar, onion)
# 128   (water, rice vinegar)
# 129   (white sugar, rice vinegar)
# 130   (white sugar, salt)
# 131   (soy sauce, vegetable oil)
# 132   (white pepper, water)
# 133   (white sugar, water)
# 134   (chilli, coriander, beansprouts)
# 135   (chilli, fish sauce, beansprouts)
# 136   (chilli, garlic, beansprouts)
# 137   (chilli, hoisin, beansprouts)
# 138   (chilli, lemon, beansprouts)
# 139   (lime, chilli, beansprouts)
# 140   (chilli, mint, beansprouts)
# 141   (chilli, oil, beansprouts)
# 142   (onion, chilli, beansprouts)
# 143   (chilli, rice vinegar, beansprouts)
# 144   (chilli, water, beansprouts)
# 145   (white sugar, chilli, beansprouts)
# 146   (fish sauce, coriander, beansprouts)
# 147   (garlic, coriander, beansprouts)
# 148   (lemon, coriander, beansprouts)
# 149   (lime, coriander, beansprouts)
# 150   (mint, coriander, beansprouts)
# 151   (oil, coriander, beansprouts)
# 152   (onion, coriander, beansprouts)
# 153   (rice vinegar, coriander, beansprouts)
# 154   (water, coriander, beansprouts)
# 155   (white sugar, coriander, beansprouts)
# 156   (garlic, fish sauce, beansprouts)
# 157   (lime, fish sauce, beansprouts)
# 158   (fish sauce, oil, beansprouts)
# 159   (onion, fish sauce, beansprouts)
# 160   (water, fish sauce, beansprouts)
# 161   (white sugar, fish sauce, beansprouts)
# 162   (lemon, garlic, beansprouts)
# 163   (lime, garlic, beansprouts)
# 164   (garlic, mint, beansprouts)
fish sauce, garlic, lemon, vegetable oil, coriander)
# 1401  (chilli, rice vinegar, lime, fish sauce, mint, garlic, coriander)
# 1402  (chilli, soy sauce, lime, fish sauce, garlic, vegetable oil, coriander)
# 1403  (chilli, soy sauce, lime, vegetable oil, fish sauce, lemon, coriander)
# 1404  (chilli, lime, oil, white sugar, water, fish sauce, coriander)
# 1405  (chilli, onion, lime, white sugar, water, fish sauce, coriander)
# 1406  (chilli, soy sauce, lime, vegetable oil, garlic, lemon, coriander)
# 1407  (chilli, lime, white sugar, water, garlic, lemon, coriander)
# 1408  (chilli, rice vinegar, lime, white sugar, garlic, mint, coriander)
# 1409  (chilli, soy sauce, lime, fish sauce, garlic, lemon, vegetable oil)
# 1410  (soy sauce, lime, fish sauce, garlic, lemon, vegetable oil, coriander)
# 1411  (chilli, lime, oil, white sugar, water, fish sauce, beansprouts, coriander)
# 1412  (chilli, onion, lime, white sugar, water, fish sauce, beansprouts, coriander)
# 1413  (chilli, lime, white sugar, water, garlic, beansprouts, lemon, coriander)
# 1414  (chilli, brown sugar, soy sauce, lime, fish sauce, garlic, lemon, coriander)
# 1415  (chilli, brown sugar, lime, fish sauce, garlic, lemon, vegetable oil, coriander)
# 1416  (chilli, brown sugar, soy sauce, fish sauce, garlic, lemon, vegetable oil, coriander)
# 1417  (chilli, brown sugar, soy sauce, lime, fish sauce, garlic, vegetable oil, coriander)
# 1418  (chilli, brown sugar, soy sauce, lime, vegetable oil, fish sauce, lemon, coriander)
# 1419  (chilli, brown sugar, soy sauce, lime, vegetable oil, garlic, lemon, coriander)
# 1420  (chilli, brown sugar, soy sauce, lime, fish sauce, garlic, lemon, vegetable oil)
# 1421  (brown sugar, soy sauce, lime, fish sauce, garlic, lemon, vegetable oil, coriander)
# 1422  (chilli, soy sauce, lime, vegetable oil, fish sauce, garlic, lemon, coriander)
# 1423  (chilli, brown sugar, soy sauce, lime, vegetable oil, fish sauce, garlic, lemon, coriander)

# %%
frequent_itemsets['itemset_length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets['cuisine'] = f'{cuisine_name}'

# %%
frequent_itemsets.groupby('itemset_length').agg({'support': 'max'})
# Out:
#                 support
# itemset_length
# 1               0.9375
# 2               0.7500
# 3               0.6250
# 4               0.5000
# 5               0.3750
# 6               0.3125
# 7               0.2500
# 8               0.2500
# 9               0.1875

# %%
# Assign max support for use later
max_support = frequent_itemsets.loc[frequent_itemsets['itemset_length'] >= 5].sort_values('support', ascending = False)['support'].iloc[0]

# %% [markdown]
# ## Filter by length and support

# %%
item_list = (frequent_itemsets.loc[frequent_itemsets['itemset_length'] == frequent_itemsets['itemset_length']
                       .max()]['itemsets']
                       .tolist()
)
item_list
# Out:
# [frozenset({'brown sugar',
#             'chilli',
#             'coriander',
#             'fish sauce',
#             'garlic',
#             'lemon',
#             'lime',
#             'soy sauce',
#             'vegetable oil'})]

# %% [markdown]
# ## TODO:
# Come up with method for breaking ties when two lists have the same support

# %% [markdown]
# # Find average quantities of each item
# ### Need to cast integer data types before grouping

# %%
# Obtain list of items in most frequent item length
common_foods = list(list(frequent_itemsets
                         .loc[frequent_itemsets['itemset_length'] == frequent_itemsets['itemset_length'].max()]['itemsets'])[0])

# %%
common_foods
common_foods.remove('water')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-768-755f102fe966> in <module>
#       1 common_foods
# ----> 2 common_foods.remove('water')
#
# ValueError: list.remove(x): x not in list

# %%
common_foods_df = df.loc[(df.name.isin(common_foods)) & (~df.amount_for_4_serves.isna())]

# %%
temp_df = (common_foods_df
 .groupby('name')
 .agg({'amount_for_4_serves': 'mean'})
 .reset_index()
           .rename(columns = {'name': 'food'})
 .assign(cuisine = cuisine_name
         , percent_recipes_using_combo = round(max_support, 2)
        , amount_for_4_serves = lambda df_: round(df_.amount_for_4_serves, 2))
)

# %%
assert len(temp_df.food) == len(common_foods), "Food missing from final dataframe"

# %%
temp_df
# Out:
#             food  amount_for_4_serves     cuisine  percent_recipes_using_combo
# 0  brown sugar    37.73                vietnamese  0.38
# 1  chilli         1.76                 vietnamese  0.38
# 2  coriander      55.17                vietnamese  0.38
# 3  fish sauce     41.01                vietnamese  0.38
# 4  garlic         2.03                 vietnamese  0.38
# 5  lemon          0.83                 vietnamese  0.38
# 6  lime           40.84                vietnamese  0.38
# 7  soy sauce      19.19                vietnamese  0.38
# 8  vegetable oil  14.21                vietnamese  0.38

# %% [markdown]
# # Add to main data set

# %%
# Run this cell for the first cuisine then comment out
#all_cuisines = pd.DataFrame(columns = ['cuisine', 'food', 'amount_for_4_serves', 'percent_recipes_using_combo'])

# %%
all_cuisines = pd.concat([all_cuisines, temp_df], sort = False)

# %%
all_cuisines
# Out:
#            cuisine                  food  amount_for_4_serves  \
# 0   chinese         chinese cooking wine  33.25
# 1   chinese         cornflour/cornstarch  23.03
# 2   chinese         garlic                2.53
# 3   chinese         onion                 12.00
# 4   chinese         sesame oil            9.03
# 5   chinese         soy sauce             25.56
# 6   french          bay leaves            1.30
# 7   french          onion                 4.74
# 8   french          parsley               19.66
# 9   french          salt                  28.92
# 10  french          thyme                 5.68
# 11  greek           black pepper          0.89
# 12  greek           garlic                2.16
# 13  greek           lemon juice           41.51
# 14  greek           olive oil             29.16
# 15  greek           oregano               4.42
# 16  greek           salt                  3.67
# 17  indian          chilli                3.49
# 18  indian          coriander             10.22
# 19  indian          cumin                 3.34
# 20  indian          garlic                4.27
# 21  indian          ginger                8.24
# 22  indian          salt                  9.95
# 23  italian         black pepper          0.76
# 24  italian         garlic                1.95
# 25  italian         olive oil             42.72
# 26  italian         salt                  10.99
# 27  italian         tomato                454.75
# 28  korean          black pepper          2.83
# 29  korean          brown sugar           27.77
# 30  korean          garlic                3.99
# 31  korean          ginger                7.14
# 32  korean          mirin                 31.00
# 33  korean          onion                 19.58
# 34  korean          sesame oil            9.71
# 35  korean          soy sauce             30.59
# 36  mediterranean   black pepper          1.20
# 37  mediterranean   garlic                2.43
# 38  mediterranean   lemon juice           43.68
# 39  mediterranean   olive oil             31.11
# 40  mediterranean   oregano               4.86
# 41  mediterranean   salt                  2.10
# 42  Mexican         black pepper          0.92
# 43  Mexican         coriander             17.48
# 44  Mexican         cumin                 4.80
# 45  Mexican         garlic                2.15
# 46  Mexican         olive oil             20.99
# 47  Mexican         salt                  1.94
# 0   middle-eastern  black pepper          0.98
# 1   middle-eastern  coriander             9.36
# 2   middle-eastern  cumin                 4.02
# 3   middle-eastern  garlic                1.25
# 4   middle-eastern  olive oil             32.86
# 5   middle-eastern  onion                 3.57
# 6   middle-eastern  salt                  3.98
# 0   south-american  black pepper          0.82
# 1   south-american  coriander             28.60
# 2   south-american  garlic                4.05
# 3   south-american  lime                  31.03
# 4   south-american  olive oil             39.16
# 5   south-american  salt                  0.84
# 0   thai            chilli                11.72
# 1   thai            coriander             22.85
# 2   thai            fish sauce            32.82
# 3   thai            garlic                7.30
# 4   thai            lemon                 1.69
# 0   vietnamese      brown sugar           37.73
# 1   vietnamese      chilli                1.76
# 2   vietnamese      coriander             55.17
# 3   vietnamese      fish sauce            41.01
# 4   vietnamese      garlic                2.03
# 5   vietnamese      lemon                 0.83
# 6   vietnamese      lime                  40.84
# 7   vietnamese      soy sauce             19.19
# 8   vietnamese      vegetable oil         14.21
#
#     percent_recipes_using_combo
# 0   0.29
# 1   0.29
# 2   0.29
# 3   0.29
# 4   0.29
# 5   0.29
# 6   0.16
# 7   0.16
# 8   0.16
# 9   0.16
# 10  0.16
# 11  0.56
# 12  0.56
# 13  0.56
# 14  0.56
# 15  0.56
# 16  0.56
# 17  0.58
# 18  0.58
# 19  0.58
# 20  0.58
# 21  0.58
# 22  0.58
# 23  0.28
# 24  0.28
# 25  0.28
# 26  0.28
# 27  0.28
# 28  0.50
# 29  0.50
# 30  0.50
# 31  0.50
# 32  0.50
# 33  0.50
# 34  0.50
# 35  0.50
# 36  0.31
# 37  0.31
# 38  0.31
# 39  0.31
# 40  0.31
# 41  0.31
# 42  0.25
# 43  0.25
# 44  0.25
# 45  0.25
# 46  0.25
# 47  0.25
# 0   0.50
# 1   0.50
# 2   0.50
# 3   0.50
# 4   0.50
# 5   0.50
# 6   0.50
# 0   0.36
# 1   0.36
# 2   0.36
# 3   0.36
# 4   0.36
# 5   0.36
# 0   0.25
# 1   0.25
# 2   0.25
# 3   0.25
# 4   0.25
# 0   0.38
# 1   0.38
# 2   0.38
# 3   0.38
# 4   0.38
# 5   0.38
# 6   0.38
# 7   0.38
# 8   0.38

# %% [markdown]
# ### Send to csv

# %%
all_cuisines.to_csv(filepath + r'\All_foods_and_quantities.csv')

# %% [markdown]
# # Create data frame with top 5 frequent itemsets in each length

# %%
# Create empty dataframe that can be populated with frequent itemsets limited to top 5
# itemsets_condensed = (pd.DataFrame(columns = {'itemsets', 'itemset_length', 'support', 'cuisine'})
#                               .reindex(columns = ['cuisine', 'itemset_length', 'itemsets', 'support']))

# %%
# This loop creates a dataframe with only the top 5 frequent itemsets in each length
# to make viewing and exporting the different combinations easy
# for i in range(1, frequent_itemsets['itemset_length'].max() + 1):
#     temp_df = (frequent_itemsets.loc[frequent_itemsets['itemset_length'] >= i]
#      .sort_values('support', ascending = False)
#      .head(1)
#     )
#     itemsets_condensed = pd.concat([itemsets_condensed, temp_df], sort = False)

# %%
# Append to all main dataframe
# itemsets_condensed_all_cuisines = pd.concat([itemsets_condensed_all_cuisines, itemsets_condensed])

# %% [markdown]
# # Send to csv

# %%
# itemsets_condensed_all_cuisines.to_csv(filepath + r'\all_cuisine_itemsets.csv')
